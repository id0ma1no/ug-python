# %%
# %matplotlib_svg
import numpy as np
from matplotlib import pyplot as plt

# %%
# 显示dot格式的图像
# f = open('fig.dot','w')
# print >> f, fig_to_dot
# f.close()

# import graphviz
# with open("fig.dot") as f:
#     dot_graph = f.read()
# graphviz.Source(dot_graph,format="svg")

# %% [markdown]
# ## 坐标变换和注释

# %%
a=np.arange(5)
print a
a[:-1]
# Out:
# [0 1 2 3 4]
# array([0, 1, 2, 3])

# %%
#%fig=为图表添加各种注释元素
def func1(x): 
    return 0.6*x + 0.3

def func2(x): 
    return 0.4*x*x + 0.1*x + 0.2
    
def find_curve_intersects(x, y1, y2):
    d = y1 - y2
    idx = np.where(d[:-1]*d[1:]<=0)[0]
    x1, x2 = x[idx], x[idx+1]
    d1, d2 = d[idx], d[idx+1]
    return -d1*(x2-x1)/(d2-d1) + x1

x = np.linspace(-3,3,100) 
f1 = func1(x)
f2 = func2(x)

plt.close("all")
fig, ax = plt.subplots(figsize=(4,2))
ax.plot(x, f1)
ax.plot(x, f2)

x1, x2 = find_curve_intersects(x, f1, f2) 
ax.plot(x1, func1(x1), "o") 
ax.plot(x2, func1(x2), "o")

ax.fill_between(x, f1, f2, where=f1 > f2, facecolor="green", alpha=0.5) #❹

from matplotlib import transforms
trans = transforms.blended_transform_factory(ax.transData, ax.transAxes)
# 创建混合坐标系, 坐标变换对象trans的X轴使用数据坐标系, 而Y轴使用子图坐标系

ax.fill_between([x1, x2], 0, 1, transform=trans, alpha=0.1) #

a = ax.text(0.05, 0.95, "Intersects",  #
    transform=ax.transAxes,
    verticalalignment = "top",
    fontsize = 8,
    bbox={"facecolor":"red","alpha":0.4,"pad":10}
)

arrow = {"arrowstyle":"fancy,tail_width=0.6", 
         "facecolor":"gray", 
         "connectionstyle":"arc3,rad=-0.3"}

ax.annotate(u"交点", #
    xy=(x1, func1(x1)), xycoords="data",
    xytext=(0.05, 0.5), textcoords="axes fraction",
    arrowprops = arrow)
                  
ax.annotate(u"交点", #
    xy=(x2, func1(x2)), xycoords="data",
    xytext=(0.05, 0.5), textcoords="axes fraction",
    arrowprops = arrow)

xm = (x1+x2)/2
ym = (func1(xm) - func2(xm))/2+func2(xm)
o = ax.annotate("Enclosed area", #
    xy =(xm, ym), xycoords="data",
    xytext = (30, -30), textcoords="offset points",    
    bbox={"boxstyle":"round", "facecolor":(1.0, 0.7, 0.7), "edgecolor":"none"},
    fontsize=8,
    arrowprops={"arrowstyle":"->"}
)

# %%
ax.fill_between??

# %% [markdown]
# ### 四种坐标系

# %% [markdown]
# * 数据坐标系, 数据的XY轴范围
# * 子图坐标系, 子图的左下标为00,右上标为11
# * 图表坐标系, 图表的左下标也用00表示
# * 窗口坐标系, 窗口是不包含标题栏,工具条以及状态栏的部分, 窗口坐标系以像素为单位,左下标也是00, 但是右上标表示的确是窗口的像素长度和像素宽度, 一个窗口下可以放读个图表

# %% [markdown]
# transData, 数据坐标对象
#
# transAxes, 子图坐标对象
#
# transFigure, 图表坐标对象
#
# 数据坐标对象和子图坐标对象可以做Axes对象的属性
#
# transFigure对象可以做图表对象的属性

# %% [markdown]
# 坐标变换对象的transform()方法, 可以实现向窗口坐标装换
# 坐标变换对象的inverted()方法, 可以实现窗口坐标系到该对象坐标系的装换

# %%
print type(ax.transData)
ax.transData.transform([(-3,-2), (3,5)])
# Out:
# <class 'matplotlib.transforms.CompositeGenericTransform'>
# array([[  40.,   16.],
#        [ 288.,  144.]])

# %%
ax.transAxes.transform([(0,0), (1,1)])
# Out:
# array([[  40.,   16.],
#        [ 288.,  144.]])

# %%
fig.transFigure.transform([(0,0), (1,1)])
# 相当于将 图表坐标系的长宽 分别乘以 80(默认像素,每英寸像素数)
# 图表坐标系是以英寸为单位的, 而窗口坐标系是以像素为单位的
# Out:
# array([[   0.,    0.],
#        [ 320.,  160.]])

# %%
inv = ax.transData.inverted()
print type(inv)
inv.transform((320, 160))
# Out:
# <class 'matplotlib.transforms.CompositeGenericTransform'>
# array([ 3.77419355,  5.875     ])

# %%
print ax.set_xlim(-3, 2) # 设置X轴的范围为-3到2
print ax.transData.transform((3, 5)) # 数据坐标变换对象已经发生了变化
# Out:
# (-3, 2)
# [ 337.6  144. ]

# %% [markdown]
# > 使用`axvspan()`和`axhspan()`可以快速绘制垂直方向和水平方向上的区间。

# %% [markdown]
# ### 坐标变换的流水线

# %%
#%fig=图表坐标变换对象的内部结构
from scpy2.common import GraphvizMPLTransform
# %dot GraphvizMPLTransform.graphviz(fig.transFigure)


fig_to_dot = GraphvizMPLTransform.graphviz(fig.transFigure)

f = open('fig.dot','w')
print >> f, fig_to_dot
f.close()

import graphviz
with open("fig.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph,format="svg")

# %%
#子图坐标变换对象的内部结构
# %dot GraphvizMPLTransform.graphviz(ax.transAxes)

fig_to_dot = GraphvizMPLTransform.graphviz(ax.transAxes)

f = open('fig.dot','w')
print >> f, fig_to_dot
f.close()

import graphviz
with open("fig.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph,format="svg")

# %%
ax.transAxes._boxout.bounds
# Out:
# (80.0, 31.999999999999993, 496.0, 256.0)

# %%
#%fig=数据坐标变换对象的内部结构
# %dot GraphvizMPLTransform.graphviz(ax.transLimits)

fig_to_dot = GraphvizMPLTransform.graphviz(ax.transLimits)

f = open('fig.dot','w')
print >> f, fig_to_dot
f.close()

import graphviz
with open("fig.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph,format="svg")

# %%
ddax.transScale
# Out:
# TransformWrapper(BlendedAffine2D(IdentityTransform(),IdentityTransform()))

# %% [markdown]
# > **WARNING**
#
# > 由于本例中的X轴的取值范围是`(-3,3)`，因此如果将X轴改为对数坐标，并且重新绘图，会产生很多错误信息。

# %%
#%fig=X轴为对数坐标时的transScale对象的内部结构
ax.set_xscale("log") # 将X轴改为对数坐标
# %dot GraphvizMPLTransform.graphviz(ax.transScale)

fig_to_dot = GraphvizMPLTransform.graphviz(ax.transScale)
f = open('fig.dot','w')
print >> f, fig_to_dot
f.close()

import graphviz
with open("fig.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph,format="svg")

# ax.set_xscale("linear") # 将X轴改为线性坐标

# %% [markdown]
# ### 制作阴影效果

# %%
#%fig=使用坐标变换绘制的带阴影的曲线
fig, ax = plt.subplots()
x = np.arange(0., 2., 0.01)
y = np.sin(2*np.pi*x)

N = 7 # 阴影的条数
for i in xrange(N, 0, -1):
    offset = transforms.ScaledTranslation(i, -i, transforms.IdentityTransform()) #❶
    shadow_trans = plt.gca().transData + offset #❷
    ax.plot(x,y,linewidth=4,color="black", 
        transform=shadow_trans,  #❸
        alpha=(N-i)/2.0/N)
    
ax.plot(x,y,linewidth=4,color='black')    
ax.set_ylim((-1.5, 1.5));

# %%
offset.transform((0,0)) # 将(0,0)变换为(1,-1)
# Out:
# array([ 1., -1.])

# %%
print ax.transData.transform((0,0)) # 对(0,0)进行数据坐标变换
print shadow_trans.transform((0,0)) # 对(0,0)进行数据坐标变换和偏移变换
# Out:
# [  60.  120.]
# [  61.  119.]

# %% [markdown]
# ### 添加注释

# %%
#%fig=三个坐标系中的文字
x = np.linspace(-1,1,11)
y = x**2

fig, ax = plt.subplots(figsize=(4,2))
ax.plot(x,y)

for i, (_x, _y) in enumerate(zip(x, y)):
    ax.text(_x, _y, str(i), color="red", fontsize=i+10) 

ax.text(0.5, 0.8, u"transAxes's Text", color="blue", ha="center", 
    transform=ax.transAxes) 
    
plt.figtext(0.1, 0.92, u"transFigure's Text", color="green") #❸;

plt.show()
# Out:
# P:\winpython\WinPython-32bit-2.7.9.2\python-2.7.9\lib\site-packages\matplotlib\font_manager.py:1282: UserWarning: findfont: Font family [u'WenQuanYi Micro Hei'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
